# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# State Appreviations
states = []

# File to Load
EPA_water_data_to_load = "../1_Input/water_system_summary_AK.csv"

# Read the EPA Water Data into Data Frame
EPA_H2O_data = pd.read_csv(EPA_water_data_to_load, encoding='utf-8')

EPA_H2O_data.head()
# Out:
#       PWS ID                      PWS Name                PWS Type  \
# 0  AK2260595                ADAK UTILITIES  Community water system
# 1  AK2250037                        AKHIOK  Community water system
# 2  AK2272747         AKIACHAK WATER SYSTEM  Community water system
# 3  AK2272005  AKIAK COMMUNITY WATER SYSTEM  Community water system
# 4  AK2260252                        AKUTAN  Community water system
#
#   Primary Source             Counties Served Cities Served  \
# 0  Surface water  Aleutians West Census Area          ADAK
# 1  Surface water       Kodiak Island Borough        AKHIOK
# 2   Ground water          Bethel Census Area      AKIACHAK
# 3   Ground water          Bethel Census Area         AKIAK
# 4  Surface water      Aleutians East Borough        AKUTAN
#
#   PopulationServed Count  Number of Facilities  Number of Violations  \
# 0                    225                     9                   508
# ...
